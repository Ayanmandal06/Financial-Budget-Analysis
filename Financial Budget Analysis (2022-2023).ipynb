# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv("E:\Ayan\dataset\Dataset.csv")
data.head()
# Out:
#                            Department /Ministry  Fund allotted(in crores)
# 0                       Ministry of Agriculture                 132513.62
# 1                   Department of Atomic Energy                  22723.58
# 2                             Ministry of Ayush                   3050.00
# 3  Department of Chemicals and Petrochemicals                      209.00
# 4                     Department of Fertilisers                 105262.23

# %%
print(data)
# Out:
#                             Department /Ministry  Fund allotted(in crores)
# 0                        Ministry of Agriculture                 132513.62
# 1                    Department of Atomic Energy                  22723.58
# 2                              Ministry of Ayush                   3050.00
# 3   Department of Chemicals and Petrochemicals                      209.00
# 4                      Department of Fertilisers                 105262.23
# ..                                           ...                       ...
# 81          Indian Audit and Accounts Department                   5620.14
# 82                             Interest Payments                 940651.02
# 83                                      Pensions                  65840.81
# 84                           Transfers to States                 334339.42
# 85                                   Grand Total                3942508.67
#
# [86 rows x 2 columns]

# %%
data = data.iloc[[0,4,13,20,46,47,48,78,84],:]
row = {'Department /Ministry': 'OTHERS', 'Fund allotted(in crores)': 2453505.68}
data = data.append(row, ignore_index = True)
print(data)
# Out:
#                          Department /Ministry  Fund allotted(in crores)
# 0                     Ministry of Agriculture                 132513.62
# 1                   Department of Fertilisers                 105262.23
# 2  Department of Food and Public Distribution                 215959.58
# 3                       MINISTRY OF EDUCATION                 104277.72
# 4                        Ministry of Railways                 140367.13
# 5     Ministry of Road Transport and Highways                 199107.71
# 6             Department of Rural Development                 135944.29
# 7                       Department of Revenue                 121231.29
# 8                         Transfers to States                 334339.42
# 9                                      OTHERS                2453505.68
# C:\Users\AYAN\AppData\Local\Temp\ipykernel_12780\1108114155.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(row, ignore_index = True)

# %%
data.plot.bar(x='Department /Ministry', y='Fund allotted(in crores)')
# Out:
# <AxesSubplot:xlabel='Department /Ministry'>

# %%
df = data["Fund allotted(in crores)"]
labels = data["Department /Ministry"]
plt.figure(figsize=(7,7))
plt.pie(df, labels=labels, autopct='%1.1f%%', startangle=90, pctdistance=0.85, shadow =True)
central_circle = plt.Circle((0, 0), 0.5, color='white')
fig = plt.gcf()
fig.gca().add_artist(central_circle)
plt.rc('font', size=12)
plt.title("Distribution of The Budget", fontsize=20)
plt.show()
